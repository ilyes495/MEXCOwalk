# %%
from lifelines.datasets import load_rossi
from lifelines import CoxPHFitter
from scipy.stats import norm

# %%
# %matplotlib inline
import os
from os import path
from glob import glob
import numpy as np
import pandas as pd
from tqdm import tqdm, trange
from utils import *

# %%
def invers_norm(data):
    rank = np.argsort(data)
    q = [0 for _ in range(len(rank))]
    for i,k in enumerate(rank):
        q[k] = i+1
    q = (np.array(q)-0.5) /len(q)
    return norm.ppf(q)

# %%
# cancer_type = 'Lung'
# cluster_num = 3
# rand_run = 4
# clinical_filename = '/home/tunthey/Dropbox/Tunde/analysis/new_datasets/' + cancer_type + '/' + cancer_type +  '_clinical_data.txt'
# drug_filename = '/home/tunthey/Dropbox/Tunde/analysis/new_datasets/' + cancer_type + '/' + cancer_type +  '_drug_data.txt'
# cluster_label = '/home/tunthey/Dropbox/Tunde/analysis/new_results/MVKKM_newdata/labels/' + cancer_type + '_mvkkm_labels_K' +  str(cluster_num) + '_random_init_run' + str(rand_run) + '_rbf_kernel_old_gamma_with_shankar_distance_second_derv.txt'
# pam50_file = '/home/tunthey/Dropbox/Tunde/analysis/PAM50/bioclassifier_R/Breastcancerpan50subtyperesult_pam50scores.txt'

# %%
# cluster_l = open(cluster_label).readlines()
# cluster_list = [s.rstrip() for s in cluster_l]
# np.array(cluster_list)
# cluster_list

# %%
# rossi_dataset = load_rossi()
# cph = CoxPHFitter()
# cph.fit(rossi_dataset, duration_col='week', event_col='arrest')

# cph.plot()

# %%
with open('../data/exp_final_gene_list.txt', 'r') as f:
    final_genes= [l.rstrip() for l in f.readlines()]
with open('../data/hint_inters_pan.txt', 'r') as f:
    hint_u_pan= [l.rstrip() for l in f.readlines()]

# %%
cancer_types = ['BLCA','BRCA','CRC', 'GBM', 'HNSC', 'KIRC', 'LAML', 'LUAD', 'LUSC', 'OV', 'UCEC']

# %%
comps = []
significant_cancers =[]
with open('../hint/out/cancer_subtype_test_results/mutex_t07_nsep_cov_nsep/cc_n100_cancer_subtype_tests.txt', 'r') as f:
    lines = f.readlines()[:]
    for i in range(0,len(lines), 12):
        comp = lines[i].strip().split('[')[-1].split(',')
        comp = [c.replace(']', '').replace('\'', '').strip() for c in comp]
        comps.append(comp)
        type_interest = [j-1 for j in range(1,12) if len(lines[i+j].split()) ==8]
        significant_cancers.append(type_interest)

# %%
cancer2modules = {}
for i,m in enumerate(comps):
    for t in significant_cancers[i]:
        if cancer_types[t] in cancer2modules.keys():
            cancer2modules[cancer_types[t]].append(m)
        else:
            cancer2modules[cancer_types[t]] = [m]

# %%
module2id = {str(m):i for i,m in enumerate(comps)}
id2module = {i:str(m) for i,m in enumerate(comps)}

# %%
cancer2modules.keys()
# Out:
# dict_keys(['HNSC', 'LAML', 'LUAD', 'KIRC', 'OV', 'BRCA', 'GBM', 'LUSC', 'UCEC', 'CRC'])

# %%
id2module[0]
# Out:
# "['POLR2A', 'SMARCA2', 'SMARCA4']"

# %%
out_path = '../hint/out/'
data_path = '../data/'
data_files = 'pancancer/'
clinic_path = data_path+'clinical_data/'
clinic_file = '{}_clinical_data.txt'
files = glob(data_path+data_files+'*/[!MANIFEST]*.txt')

# %%
cancer2file = {c.split('/')[-1].split('.')[0]:c for c in files}

# %%
df = pd.read_csv(cancer2file['OV'], delimiter = '\t', low_memory=False)
df.drop(df.index[0], inplace=True)
gene_and_id = df.iloc[:, 0].values
df.index = final_genes
df.drop(df.columns[0], axis=1, inplace= True)
df = df.loc[list(hint_u_pan)]

# %%
df_ = df.T
df_.index.names = ['patients']
df_.columns.name = 'genes'

# %%
ids= [s.split('-')[3] for s in df_.index]

# %%
np.unique(ids, return_counts=True)
# Out:
# (array(['01A', '01B', '01C', '01R', '02A'], dtype='<U3'),
#  array([292,   9,   1,   1,   4]))

# %%
names = ['-'.join(x.split('-')[:3]) for x in df_.index]
unique = np.unique(names, return_counts=True)

# %%
keep_patient = [x.split('-')[3][:2] == '01' for x in df_.index]
df_ = df_.loc[keep_patient]

# %%
df_.shape
# Out:
# (303, 9523)

# %%
df_.index = ['-'.join(x.split('-')[:3]) for x in df_.index]
df_.index.names = ['patients']

# %%
# df_.loc['TCGA-04-1348']

# %%
# np.unique(df_.index.values, return_counts=True)

# %%
from rank_based_inverse_normal_transformation import *

# %%
df3 = df_.apply(invers_norm, axis = 0)

# %%
df2 = df_clinical.join(df3)

# %%
df2 = df2.loc[~df2[df2.columns[4:]].isnull().any(axis=1)]

# %%
df2[~df2[df2.columns[4:]].isnull().any(axis=1)]
# Out:
#               event  time_to_event  days_to_last_followup  days_to_last_alive  \
# patients
# TCGA-09-2054      0          637.0                  637.0               637.0
# TCGA-13-1481      0         2648.0                 2648.0              2648.0
# TCGA-23-1027      0          976.0                  966.0               966.0
# TCGA-23-1109      0         1562.0                 1562.0              1562.0
# TCGA-23-1114      0         2089.0                 2089.0              2089.0
# TCGA-24-0975      0          663.0                  663.0               663.0
# TCGA-24-1103      0         1646.0                 1646.0              1646.0
# TCGA-24-1430      0          863.0                  863.0               863.0
# TCGA-24-1434      0          568.0                  568.0               568.0
# TCGA-24-1435      0         1324.0                 1324.0              1324.0
# TCGA-24-1436      0          260.0                  260.0               260.0
# TCGA-24-1463      0         2218.0                 2218.0              2218.0
# TCGA-24-1467      0         3224.0                 3224.0              3224.0
# TCGA-24-1474      0          676.0                  676.0               676.0
# TCGA-24-1544      0          820.0                  820.0               820.0
# TCGA-24-1545      0         1746.0                 1746.0              1746.0
# TCGA-24-1546      0         1955.0                 1955.0              1955.0
# TCGA-24-1548      0          493.0                  493.0               493.0
# TCGA-24-1549      0         1721.0                 1721.0              1721.0
# TCGA-24-1550      0         1249.0                 1249.0              1249.0
# TCGA-24-1551      0         1579.0                 1579.0              1579.0
# TCGA-24-1552      0         1259.0                 1259.0              1259.0
# TCGA-24-1553      0         1767.0                 1767.0              1767.0
# TCGA-24-1555      0         2692.0                 2692.0              2692.0
# TCGA-24-1556      0         2148.0                 2148.0              2148.0
# TCGA-24-1557      0         1213.0                 1213.0              1213.0
# TCGA-24-1558      0          594.0                  594.0               594.0
# TCGA-24-1560      0         1341.0                 1341.0              1341.0
# TCGA-24-1562      0         1384.0                 1384.0              1384.0
# TCGA-24-1563      0         1451.0                 1451.0              1451.0
# ...             ...            ...                    ...                 ...
# TCGA-29-1785      0         1104.0                 1053.0              1053.0
# TCGA-29-2414      0         2621.0                 2621.0              2621.0
# TCGA-30-1718      0         1579.0                 1579.0              1579.0
# TCGA-30-1855      0           75.0                   75.0                75.0
# TCGA-30-1857      0            8.0                    8.0                 8.0
# TCGA-30-1860      0         1366.0                 1366.0              1366.0
# TCGA-30-1861      0         1058.0                 1058.0              1058.0
# TCGA-30-1862      0          186.0                  186.0               186.0
# TCGA-30-1891      0          914.0                  914.0               914.0
# TCGA-36-1571      0          695.0                  695.0               695.0
# TCGA-36-1580      0          737.0                  737.0               737.0
# TCGA-57-1582      0          731.0                  731.0               731.0
# TCGA-57-1583      0          346.0                  346.0               346.0
# TCGA-57-1585      0           53.0                   53.0                53.0
# TCGA-61-1724      0          637.0                  637.0               637.0
# TCGA-61-1736      0         1484.0                 1484.0              1484.0
# TCGA-61-1738      0         1089.0                 1089.0              1089.0
# TCGA-61-1740      0           74.0                   74.0                74.0
# TCGA-61-1741      0         1024.0                 1024.0              1024.0
# TCGA-61-1743      0         1329.0                 1329.0              1329.0
# TCGA-61-1917      0         1321.0                 1321.0              1321.0
# TCGA-61-1918      0          479.0                  479.0               479.0
# TCGA-61-1919      0         1161.0                 1161.0              1161.0
# TCGA-61-2102      0          197.0                  197.0               197.0
# TCGA-61-2109      0          629.0                  629.0               629.0
# TCGA-61-2110      0         1354.0                 1354.0              1354.0
# TCGA-61-2113      0          676.0                  676.0               676.0
# TCGA-10-0928      0          563.0                  563.0               563.0
# TCGA-10-0936      0         1123.0                 1089.0              1089.0
# TCGA-13-0893      0         1319.0                 1319.0              1319.0
#
#               days_to_death vital_status  age  gender  histology     NUP98  \
# patients
# TCGA-09-2054          637.0         dead   58       1          2  0.435270
# TCGA-13-1481         2648.0         dead   76       1          2 -0.049657
# TCGA-23-1027          976.0         dead   48       1          2 -2.093510
# TCGA-23-1109         1562.0         dead   62       1          2  0.302362
# TCGA-23-1114         2089.0         dead   55       1          2 -0.390226
# TCGA-24-0975          663.0         dead   58       1          2 -1.964217
# TCGA-24-1103         1646.0         dead   50       1          2  2.938285
# TCGA-24-1430          863.0         dead   68       1          2  0.941332
# TCGA-24-1434          568.0         dead   59       1          2  0.831058
# TCGA-24-1435         1324.0         dead   57       1          2 -1.277799
# TCGA-24-1436          260.0         dead   57       1          2 -0.302362
# TCGA-24-1463         2218.0         dead   70       1          2 -0.785188
# TCGA-24-1467         3224.0         dead   51       1          2  0.556956
# TCGA-24-1474          676.0         dead   57       1          2  0.311033
# TCGA-24-1544          820.0         dead   71       1          2 -0.490525
# TCGA-24-1545         1746.0         dead   69       1          2 -0.141103
# TCGA-24-1546         1955.0         dead   46       1          2 -0.363580
# TCGA-24-1548          493.0         dead   57       1          2  1.964217
# TCGA-24-1549         1721.0         dead   58       1          2  1.573896
# TCGA-24-1550         1249.0         dead   49       1          2 -0.556956
# TCGA-24-1551         1579.0         dead   53       1          2  1.124677
# TCGA-24-1552         1259.0         dead   77       1          2  1.519197
# TCGA-24-1553         1767.0         dead   53       1          2 -0.481216
# TCGA-24-1555         2692.0         dead   50       1          2  1.296743
# TCGA-24-1556         2148.0         dead   50       1          2 -0.499877
# TCGA-24-1557         1213.0         dead   49       1          2  0.242257
# TCGA-24-1558          594.0         dead   73       1          2  0.625942
# TCGA-24-1560         1341.0         dead   51       1          2  1.035726
# TCGA-24-1562         1384.0         dead   67       1          2 -1.064442
# TCGA-24-1563         1451.0         dead   66       1          2 -1.573896
# ...                     ...          ...  ...     ...        ...       ...
# TCGA-29-1785         1104.0         dead   55       1          2 -0.016546
# TCGA-29-2414         2621.0         dead   75       1          2 -1.356571
# TCGA-30-1718         1579.0         dead   44       1          2 -0.878748
# TCGA-30-1855           75.0         dead   61       1          2  0.903357
# TCGA-30-1857            8.0         dead   64       1          2 -1.633755
# TCGA-30-1860         1366.0         dead   58       1          2 -1.189295
# TCGA-30-1861         1058.0         dead   74       1          2 -0.311033
# TCGA-30-1862          186.0         dead   65       1          2 -1.666019
# TCGA-30-1891          914.0         dead   61       1          2 -1.377632
# TCGA-36-1571          695.0         dead   53       1          2  1.377632
# TCGA-36-1580          737.0         dead   82       1          2  0.819430
# TCGA-57-1582          731.0         dead   50       1          2  0.363580
# TCGA-57-1583          346.0         dead   57       1          2  0.453533
# TCGA-57-1585           53.0         dead   57       1          2 -1.545968
# TCGA-61-1724          637.0         dead   47       1          2 -0.762864
# TCGA-61-1736         1484.0         dead   45       1          2  1.206246
# TCGA-61-1738         1089.0         dead   60       1          2 -0.677088
# TCGA-61-1740           74.0         dead   71       1          2 -0.719314
# TCGA-61-1741         1024.0         dead   76       1          2  0.372432
# TCGA-61-1743         1329.0         dead   53       1          2 -0.033097
# TCGA-61-1917         1321.0         dead   60       1          2  0.074523
# TCGA-61-1918          479.0         dead   45       1          2  0.698046
# TCGA-61-1919         1161.0         dead   58       1          2 -0.337190
# TCGA-61-2102          197.0         dead   74       1          2  0.293713
# TCGA-61-2109          629.0         dead   40       1          2 -0.399169
# TCGA-61-2110         1354.0         dead   56       1          2  0.490525
# TCGA-61-2113          676.0         dead   53       1          2  0.730071
# TCGA-10-0928          563.0         dead   71       1          2 -0.426193
# TCGA-10-0936         1123.0         dead   69       1          2 -1.049976
# TCGA-13-0893         1319.0         dead   48       1          2  0.518714
#
#                 ...         LCA5    CACNB2      AMPH     GNG10    COMTD1  \
# patients        ...
# TCGA-09-2054    ...     0.000000  0.124411 -0.311033 -0.677088 -1.736314
# TCGA-13-1481    ...    -0.082822 -0.372432  0.363580  0.417151  0.199868
# TCGA-23-1027    ...     1.468700  1.007840  0.116078  1.816414 -1.519197
# TCGA-23-1109    ...    -1.035726  0.471948 -0.267897  0.302362 -2.938285
# TCGA-23-1114    ...     0.954296  0.666721 -0.399169  0.242257 -0.967422
# TCGA-24-0975    ...    -0.149463 -0.576383  0.785188  0.941332  0.319727
# TCGA-24-1103    ...     0.471948  1.223550  0.216776 -1.700117  0.740914
# TCGA-24-1430    ...     0.302362  1.421693 -0.708640 -1.444797 -0.390226
# TCGA-24-1434    ...     0.033097 -0.149463 -1.021684 -1.603108 -0.576383
# TCGA-24-1435    ...    -0.250785  0.285087 -1.493473  1.124677  0.586178
# TCGA-24-1436    ...    -0.354756  0.174610  1.700117 -0.149463  0.499877
# TCGA-24-1463    ...    -0.471948 -0.954296 -0.556956 -2.579268  0.796498
# TCGA-24-1467    ...     0.586178 -0.091126 -0.656424 -0.107753 -1.064442
# TCGA-24-1474    ...     0.417151 -1.545968 -1.189295 -0.233747 -0.490525
# TCGA-24-1544    ...     0.381314  1.736314  1.573896 -0.426193  0.537736
# TCGA-24-1545    ...    -0.796498  1.910214  0.490525  0.528201  0.183016
# TCGA-24-1546    ...    -1.468700 -0.302362 -1.399323  0.740914  0.408144
# TCGA-24-1548    ...     0.285087 -0.453533  0.518714  0.537736 -0.311033
# TCGA-24-1549    ...     0.730071  0.903357  0.605940  0.435270  0.941332
# TCGA-24-1550    ...    -0.444383  1.493473  1.259303  0.462721 -0.994187
# TCGA-24-1551    ...    -0.132752 -0.677088 -1.666019  0.646197 -0.646197
# TCGA-24-1552    ...    -0.208314 -1.259303  0.250785  1.277799 -2.093510
# TCGA-24-1553    ...    -1.189295 -1.573896 -0.363580  0.471948  0.390226
# TCGA-24-1555    ...    -0.785188  0.556956 -1.035726  2.093510  0.751843
# TCGA-24-1556    ...     0.372432 -0.276482 -0.980716 -0.481216 -1.259303
# TCGA-24-1557    ...     0.116078 -1.493473 -0.293713 -2.174029  1.277799
# TCGA-24-1558    ...    -0.967422  1.021684 -1.700117 -0.890985 -0.890985
# TCGA-24-1560    ...    -0.099436 -1.124677 -0.677088  0.796498 -1.156382
# TCGA-24-1562    ...    -0.866641 -0.646197 -0.537736 -0.740914  0.605940
# TCGA-24-1563    ...     0.174610 -0.842801 -1.007840  0.141103 -1.964217
# ...             ...          ...       ...       ...       ...       ...
# TCGA-29-1785    ...    -0.225253  1.296743 -1.277799 -1.861268 -0.730071
# TCGA-29-2414    ...     0.636037 -0.132752  0.596030  1.021684 -0.225253
# TCGA-30-1718    ...    -1.399323  1.519197  0.099436 -0.566642  0.490525
# TCGA-30-1855    ...    -1.700117 -1.021684  0.225253  0.854660  1.223550
# TCGA-30-1857    ...     1.736314 -0.518714  1.049976 -0.372432 -0.199868
# TCGA-30-1860    ...    -0.276482 -2.093510  2.938285  0.066230 -1.241228
# TCGA-30-1861    ...     1.172680 -0.547321 -0.666721 -2.938285 -0.762864
# TCGA-30-1862    ...     0.967422 -0.471948  0.132752  1.140386 -1.316165
# TCGA-30-1891    ...     0.363580 -0.719314 -0.566642 -2.397627  0.687529
# TCGA-36-1571    ...    -0.576383 -0.033097 -0.646197 -1.035726 -0.878748
# TCGA-36-1580    ...    -0.293713  0.276482  1.035726 -0.293713 -0.773978
# TCGA-57-1582    ...     0.807911  1.633755  1.545968  1.444797  0.994187
# TCGA-57-1583    ...     1.573896 -0.481216  0.819430 -0.259331 -0.399169
# TCGA-57-1585    ...    -0.547321 -0.074523  1.666019 -0.528201 -0.842801
# TCGA-61-1724    ...     0.576383 -0.174610  0.337190 -1.421693  1.316165
# TCGA-61-1736    ...     0.708640 -0.066230 -0.250785  0.233747  1.421693
# TCGA-61-1738    ...     1.223550  0.719314  0.842801 -0.074523  0.566642
# TCGA-61-1740    ...    -1.736314  0.259331 -0.586178  1.964217  2.271738
# TCGA-61-1741    ...     0.762864  0.208314  0.124411 -1.049976  0.481216
# TCGA-61-1743    ...    -0.233747 -0.016546 -1.377632 -0.666721  1.603108
# TCGA-61-1917    ...    -2.093510 -1.172680  0.267897 -2.271738 -0.276482
# TCGA-61-1918    ...    -0.773978  0.033097 -1.079134  0.337190  0.556956
# TCGA-61-1919    ...    -1.172680 -0.199868 -0.132752  0.967422  0.666721
# TCGA-61-2102    ...     2.271738 -0.915868  0.082822  0.751843  1.545968
# TCGA-61-2109    ...    -1.007840  1.259303 -2.271738  0.719314  1.064442
# TCGA-61-2110    ...    -0.426193 -0.049657 -0.024821 -0.556956 -0.166216
# TCGA-61-2113    ...     0.208314  0.499877 -1.241228 -0.751843 -0.586178
# TCGA-10-0928    ...     0.199868 -1.140386  1.468700 -1.519197  0.785188
# TCGA-10-0936    ...    -0.854660 -0.328446 -0.698046 -1.189295 -1.545968
# TCGA-13-0893    ...     0.166216  1.189295 -0.994187 -0.124411  1.356571
#
#                   KNG1     RRAGB     RRAGC     TMED2     TRPT1
# patients
# TCGA-09-2054  0.453533  2.093510 -0.566642 -0.537736  0.049657
# TCGA-13-1481  0.216776 -0.636037  0.174610  0.250785 -1.296743
# TCGA-23-1027  0.141103 -0.915868 -1.736314 -0.708640 -1.700117
# TCGA-23-1109  1.156382 -1.079134 -0.878748 -0.408144 -1.774941
# TCGA-23-1114  0.174610 -0.066230 -0.586178  0.408144 -0.967422
# TCGA-24-0975 -0.141103  0.132752 -0.216776  0.099436  2.397627
# TCGA-24-1103 -0.132752 -0.656424 -1.910214 -1.094063 -1.336095
# TCGA-24-1430  0.233747  1.241228 -0.116078  1.156382  0.157834
# TCGA-24-1434  0.225253 -1.816414  0.399169  0.831058 -0.698046
# TCGA-24-1435  0.954296  0.807911  0.941332  0.807911  1.021684
# TCGA-24-1436  0.490525 -1.021684  0.636037  0.116078  0.250785
# TCGA-24-1463  0.499877 -1.421693  0.842801  1.259303 -0.033097
# TCGA-24-1467  0.528201 -0.547321  0.132752  0.751843 -1.223550
# TCGA-24-1474  0.547321 -0.259331  0.903357  0.890985 -0.666721
# TCGA-24-1544  0.556956  0.216776 -1.189295  0.499877  0.462721
# TCGA-24-1545  0.566642  0.980716  0.199868 -1.007840 -0.174610
# TCGA-24-1546  0.967422 -0.242257 -0.605940  2.271738  1.316165
# TCGA-24-1548  0.576383  1.124677 -0.267897  1.633755 -0.426193
# TCGA-24-1549  0.586178 -0.462721  0.677088 -1.079134 -0.216776
# TCGA-24-1550  0.605940  1.816414  1.172680 -1.816414 -0.605940
# TCGA-24-1551  0.677088 -0.141103 -0.157834  0.399169  0.099436
# TCGA-24-1552  0.615910 -1.007840  0.471948 -2.579268  0.785188
# TCGA-24-1553  0.625942 -0.166216  0.008273 -0.099436  0.311033
# TCGA-24-1555  0.730071  0.773978 -0.490525  1.910214 -0.646197
# TCGA-24-1556  0.636037 -1.444797  0.057941  0.954296  0.390226
# TCGA-24-1557  0.646197  0.994187 -0.426193 -0.082822  0.319727
# TCGA-24-1558  0.666721  2.397627  1.774941 -1.573896  0.708640
# TCGA-24-1560  0.481216 -1.603108  1.493473  1.816414  1.421693
# TCGA-24-1562  0.596030  0.605940 -0.276482 -1.468700 -0.276482
# TCGA-24-1563  1.172680 -0.199868 -0.762864 -0.842801  1.603108
# ...                ...       ...       ...       ...       ...
# TCGA-29-1785 -1.336095  0.141103 -1.124677 -1.356571  0.890985
# TCGA-29-2414 -1.316165  1.736314 -1.603108 -0.677088  0.337190
# TCGA-30-1718 -0.796498 -1.700117  0.831058 -1.189295 -2.174029
# TCGA-30-1855 -0.462721 -0.854660  1.910214  1.377632  1.573896
# TCGA-30-1857 -0.453533 -1.140386 -1.094063 -0.615910 -1.377632
# TCGA-30-1860 -0.444383 -1.493473  1.021684  0.132752 -2.397627
# TCGA-30-1861 -0.435270  0.915868  1.241228 -0.049657 -0.242257
# TCGA-30-1862 -0.426193 -0.719314  0.490525 -0.337190  0.490525
# TCGA-30-1891 -0.417151  0.116078  1.421693  1.296743 -2.024641
# TCGA-36-1571 -0.328446 -1.336095 -0.656424 -0.941332  0.183016
# TCGA-36-1580  0.941332  0.267897  1.573896  1.399323 -0.566642
# TCGA-57-1582 -0.293713 -1.189295 -0.225253  0.819430  0.267897
# TCGA-57-1583 -0.285087  0.730071  0.528201  1.223550 -0.687529
# TCGA-57-1585 -0.267897  0.285087  0.242257 -0.345960 -0.762864
# TCGA-61-1724  0.854660 -0.124411 -2.579268  0.354756 -1.241228
# TCGA-61-1736 -0.481216 -1.468700 -1.140386  0.636037  0.166216
# TCGA-61-1738 -0.785188  0.074523  1.316165  1.493473 -1.861268
# TCGA-61-1740 -0.773978 -0.293713 -0.099436  0.842801  1.493473
# TCGA-61-1741  1.816414 -1.573896 -0.124411 -0.319727 -0.576383
# TCGA-61-1743 -0.762864  1.296743 -0.556956  1.519197  0.132752
# TCGA-61-1917 -0.730071  0.719314 -1.109240  0.311033  2.579268
# TCGA-61-1918 -0.719314  0.099436  2.397627 -2.271738 -0.399169
# TCGA-61-1919  1.356571 -0.819430  0.000000  0.625942  1.189295
# TCGA-61-2102 -0.547321 -0.586178  0.547321  0.242257 -0.819430
# TCGA-61-2109  1.700117 -0.267897  0.928525 -0.687529 -0.807911
# TCGA-61-2110  1.206246  0.625942 -0.831058 -0.199868  0.233747
# TCGA-61-2113 -0.528201 -0.928525  0.426193 -0.016546 -1.007840
# TCGA-10-0928 -0.024821 -0.319727  0.166216 -0.636037  0.576383
# TCGA-10-0936 -0.066230  1.223550 -2.093510 -0.566642  2.093510
# TCGA-13-0893 -0.149463 -0.363580  0.381314 -0.008273  0.903357
#
# [141 rows x 9532 columns]

# %%
df_.head()
# Out:
# genes                             NUP98   ZKSCAN5    LRRC7     RHO     WASH3P  \
# patients
# TCGA-04-1348-01A-01R-1565-13  2595.3213  412.4765   3.4956  0.2689   739.4461
# TCGA-04-1357-01A-01R-1565-13  1252.6042  501.9531   0.0000  0.0000   393.2292
# TCGA-04-1362-01A-01R-1565-13  1877.5287  223.7281   1.9858  4.6334   715.5327
# TCGA-04-1364-01A-01R-1565-13  2235.0277  694.5505   0.0000  0.0000  1021.4725
# TCGA-04-1365-01A-01R-1565-13  1647.1297  423.0827  62.6789  2.1094   813.9220
#
# genes                           KIF21B      LASP1  C2orf62     FSTL3  \
# patients
# TCGA-04-1348-01A-01R-1565-13   93.3047  4250.3361   8.0667  213.7671
# TCGA-04-1357-01A-01R-1565-13  315.7552  4565.7552   3.9062  289.7135
# TCGA-04-1362-01A-01R-1565-13  176.4010  5779.8628   2.6477  183.6821
# TCGA-04-1364-01A-01R-1565-13  360.4200  3575.3659  26.2895  289.1840
# TCGA-04-1365-01A-01R-1565-13   86.4849  5431.9723   8.1362  231.1285
#
# genes                             ITPR3    ...          LCA5   CACNB2  \
# patients                                   ...
# TCGA-04-1348-01A-01R-1565-13  2736.2087    ...       33.8801  13.4445
# TCGA-04-1357-01A-01R-1565-13  3390.9115    ...       73.5677  20.1823
# TCGA-04-1362-01A-01R-1565-13  4397.7263    ...      228.6925  17.2099
# TCGA-04-1364-01A-01R-1565-13   818.3611    ...      172.1535  17.3850
# TCGA-04-1365-01A-01R-1565-13  3265.2192    ...      106.0720  12.9577
#
# genes                             AMPH      GNG10    COMTD1    KNG1     RRAGB  \
# patients
# TCGA-04-1348-01A-01R-1565-13    6.9911   764.6276  434.5254  0.0000  267.0073
# TCGA-04-1357-01A-01R-1565-13  234.3750   542.3177  326.8229  0.0000  261.0677
# TCGA-04-1362-01A-01R-1565-13   53.6153  1664.7223  439.8441  0.3310  285.2864
# TCGA-04-1364-01A-01R-1565-13   17.3850   652.1481  981.1903  0.0000   80.9885
# TCGA-04-1365-01A-01R-1565-13   29.8328   809.4018  467.6812  0.0000  155.7933
#
# genes                            RRAGC      TMED2      TRPT1
# patients
# TCGA-04-1348-01A-01R-1565-13  219.0777  9459.5321   670.6104
# TCGA-04-1357-01A-01R-1565-13  281.2500  6087.8906   571.6146
# TCGA-04-1362-01A-01R-1565-13  311.7135  8183.6159   894.9123
# TCGA-04-1364-01A-01R-1565-13  162.6978  6663.1049   552.9266
# TCGA-04-1365-01A-01R-1565-13  278.1377  9837.5772  1042.0371
#
# [5 rows x 9523 columns]

# %%
df2.shape
# Out:
# (152, 9527)

# %%
for module in cancer2modules['LAML']:

        module_id = module2id[str(module)]
#         if not os.path.exists(results_path+'{}/'.format(module_id)):
#             os.mkdir(results_path+'{}/'.format(module_id))
#         csv_path = results_path+'{}/{}.csv'.format(module_id, cancer)
        df2 = df2.astype('float')
        tmp_df  = df2[module+['event','time_to_event']]
        cph = CoxPHFitter()
        cph.fit(tmp_df, duration_col='time_to_event', event_col='event', show_progress=False)
        s = cph.summary

# %%
clinical_data = clinic_file.format('OV')
df_clinical = pd.read_csv(clinic_path+clinical_data,usecols = ['patient_id','age', 'gender','event','time_to_event'], delimiter = '\t', low_memory=False)

# %%
df_clinical = df_clinical.set_index('patient_id')
df_clinical.index.names = ['patients']
#df_clinic.set_index('patient_id')

# %%
df_clinical =df_clinical[~df_clinical.isnull().any(axis=1)]

# %%
df_clinical[df_clinical.isnull().any(axis=1) == True]
# Out:
# Empty DataFrame
# Columns: [event, time_to_event, days_to_last_followup, days_to_last_alive, days_to_death, vital_status, age, gender, histology]
# Index: []

# %%
df_clinical.shape
# Out:
# (230, 9)

# %%
df_clinical.head()
# Out:
#               event  time_to_event  days_to_last_followup  days_to_last_alive  \
# patients
# TCGA-04-1331      0         1336.0                 1224.0              1224.0
# TCGA-04-1332      0         1247.0                 1247.0              1247.0
# TCGA-09-2054      0          637.0                  637.0               637.0
# TCGA-13-1477      0         1662.0                 1662.0              1662.0
# TCGA-13-1481      0         2648.0                 2648.0              2648.0
#
#               days_to_death vital_status  age  gender  histology
# patients
# TCGA-04-1331         1336.0         dead   78       1          2
# TCGA-04-1332         1247.0         dead   70       1          2
# TCGA-09-2054          637.0         dead   58       1          2
# TCGA-13-1477         1662.0         dead   49       1          2
# TCGA-13-1481         2648.0         dead   76       1          2

# %%
df1 = df_.astype('float')

# %%
tmp_df  = df2[['NOTCH1']+['age','gender','event','time_to_event']].astype('float')
cph = CoxPHFitter()
cph.fit(tmp_df, duration_col='time_to_event', event_col='event', show_progress=False)
# Out:
# <lifelines.CoxPHFitter: fitted with 152 observations, 32 censored>

# %%
s = cph.summary

# %%
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 152 observations, 32 censored>
#       duration col = 'time_to_event'
#          event col = 'event'
# number of subjects = 152
#   number of events = 120
#     log-likelihood = -471.96
#   time fit was run = 2019-01-24 06:22:22 UTC
#
# ---
#         coef  exp(coef)  se(coef)     z      p  log(p)  lower 0.95  upper 0.95
# NOTCH1 -0.10       0.90      0.10 -1.06   0.29   -1.24       -0.29        0.09
# age     0.03       1.03      0.01  3.66 <0.005   -8.29        0.01        0.04  **
# gender  0.12       1.13      0.19  0.62   0.53   -0.63       -0.26        0.50
# ---
# Signif. codes: 0 '***' 0.0001 '**' 0.001 '*' 0.01 '.' 0.05 ' ' 1
#
# Concordance = 0.61
# Likelihood ratio test = 15.49 on 3 df, log(p)=-6.54

# %%
s
# Out:
#             coef  exp(coef)  se(coef)         z         p    log(p)  \
# NOTCH1 -0.101338   0.903628  0.095587 -1.060160  0.289072 -1.241081
# age     0.027775   1.028164  0.007584  3.662381  0.000250 -8.294521
# gender  0.120577   1.128147  0.194207  0.620868  0.534687 -0.626075
#
#         lower 0.95  upper 0.95
# NOTCH1   -0.288685    0.086010
# age       0.012911    0.042639
# gender   -0.260061    0.501214

# %%
from cox_utils import *

# %%
# Data is [[Patient ID, time (days), vital status, 0, sex, age at diagnosis],...]
clinical = np.array(load_clinical())

# %%
clinical[:5]
# Out:
# array([['TCGA-02-0001', '358', 'Dead', '0', '1', '44'],
#        ['TCGA-02-0003', '144', 'Dead', '0', '0', '50'],
#        ['TCGA-02-0004', '345', 'Dead', '0', '0', '59'],
#        ['TCGA-02-0006', '558', 'Dead', '0', '1', '56'],
#        ['TCGA-02-0007', '705', 'Dead', '0', '1', '40']], dtype='<U12')

# %%
data = {'patients':clinical[:,0],
       'time_to_event':clinical[:,1],
        'event': [1 if s == 'Dead' else 0 for s in clinical[:,2]],
        'gender': clinical[:,4],
        'age': clinical[:,5]
        
       }

# %%
df_clinical = pd.DataFrame(data,)

# %%
df_clinical = df_clinical.set_index('patients')
df_clinical =df_clinical[~df_clinical.isnull().any(axis=1)]

# %%
df_clinical.shape
# Out:
# (595, 5)

# %%
df_clinical.head()
# Out:
#              time_to_event  event gender age
# patients
# TCGA-02-0001           358      1      1  44
# TCGA-02-0003           144      1      0  50
# TCGA-02-0004           345      1      0  59
# TCGA-02-0006           558      1      1  56
# TCGA-02-0007           705      1      1  40

# %%
df_clinical.loc['TCGA-14-1829']
# Out:
# time_to_event    218
# event              0
# gender             0
# age               57
# Name: TCGA-14-1829, dtype: object

# %%
df_.loc['TCGA-14-1829']['NOTCH1']
# Out:
# '378.6248'

# %%
clinical_names = set(df_clinical.index.values)
exp_names = set(df_.index)

# %%
len(clinical_names)
# Out:
# 595

# %%
clinical_names.intersection(exp_names)
# Out:
# set()

# %%
st = '0.39460475 0.15091132 0.43753911 0.65392753 0.51048247 0.47433630 0.00711546 0.12695813 0.74702367 0.9163484'
data = np.array([float(s) for s in st.split()])

# %%
rank = np.argsort(data)
rank
# Out:
# array([6, 7, 1, 0, 2, 5, 4, 3, 8, 9])

# %%
q = [0 for _ in range(len(rank))]
for i,k in enumerate(rank):
    q[k] = i+1
q = (np.array(q)-0.5) /len(q)
q
# Out:
# array([0.35, 0.25, 0.45, 0.75, 0.65, 0.55, 0.05, 0.15, 0.85, 0.95])

# %%
from scipy.stats import norm

# %%
norm.ppf(q)
# Out:
# array([-0.38532047, -0.67448975, -0.12566135,  0.67448975,  0.38532047,
#         0.12566135, -1.64485363, -1.03643339,  1.03643339,  1.64485363])

# %%
def invers_norm(data):
    rank = np.argsort(data)
    q = [0 for _ in range(len(rank))]
    for i,k in enumerate(rank):
        q[k] = i+1
    q = (np.array(q)-0.5) /len(q)
    return norm.ppf(q)
